# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/NAJAM2005/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My lane: decline_recovery
#
# I'm choosing the `decline_recovery` lane. In the Week 1 starter notebook, I found that
# 54.2% of the 30,000-page sample is already labeled as declining — this is not a rare
# edge case, it's over half the content base. A model that helps prioritize which
# declining pages are worth reviewing first has clear, immediate value for an SEO team
# managing hundreds or thousands of pages with limited editor time.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os, subprocess, sys

if not os.path.exists("flyrank-ml-internship"):
    subprocess.run(["git", "clone", "https://github.com/NAJAM2005/flyrank-ml-internship.git"])
os.chdir("flyrank-ml-internship")
print("Working dir:", os.getcwd())
# Out:
# Working dir: /content/flyrank-ml-internship/flyrank-ml-internship

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## The question
#
# **Unit of analysis:** a page (not a client, not a day) — one row per content item.
#
# **Search question:** Given a page that is currently declining, which observable,
# pre-decision signals (traffic pattern, position, engagement, freshness) best predict
# whether it's worth prioritizing for review this sprint?
#
# **Decision it improves:** which declining pages an editor reviews first, out of a
# backlog too large to review all at once.
#
# **Action someone takes:** an SEO editor pulls the top-ranked pages from the model's
# queue and schedules them for a content refresh instead of picking pages ad hoc.
#
# **Cost of a wrong call:**
# - False positive: wasted editor hours on a page that wasn't really a priority.
# - False negative: a real decliner goes unnoticed and keeps losing traffic.
#
# **Why data/ML helps:** with hundreds of pages declining at once, no one can manually
# check every signal for every page. A ranked model turns an unmanageable list into a
# short, defensible queue.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

declining_rate = (df["trend_direction"] == "down").mean()
print(f"Declining rate: {declining_rate:.3f} ({declining_rate*100:.1f}% of {len(df)} pages)")

visible = df[df["impressions_90d"] >= 100]
ctr_by_pos = visible.groupby("position_tier")["ctr"].mean().sort_values(ascending=False)
print("\nMean CTR by position tier:")
print(ctr_by_pos.round(4))

wc = df.groupby("trend_direction")["word_count"].median()
print("\nMedian word count by trend direction:")
print(wc.round(0))
print("\n'down' and 'up' pages have almost identical median word count — length alone won't predict decline.")
# Out:
# Declining rate: 0.542 (54.2% of 30000 pages)
#
# Mean CTR by position tier:
# position_tier
# page_1      0.3548
# top_3       0.3341
# striking    0.2558
# page_3_5    0.1424
# deep        0.0554
# Name: ctr, dtype: float64
#
# Median word count by trend direction:
# trend_direction
# down      2909.0
# flat      2698.0
# new       2239.0
# stable    2912.0
# up        2848.0
# Name: word_count, dtype: float64
#
# 'down' and 'up' pages have almost identical median word count — length alone won't predict decline.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful words: what I can and can't claim
#
# - I can say these patterns are observed and directional in this anonymized sample —
#   not proof of causation, and not a claim about Google's actual algorithm.
# - "Declining" here is a label already computed in the data (`trend_direction`), not
#   something I've independently verified.
# - Word count showing no relationship to decline doesn't mean length never matters —
#   it isn't the dominant lever in this dataset, at this snapshot in time.
# - I will not claim my model "detects Google's real ranking factors" — only that it
#   ranks pages by a learned, testable pattern in this sample.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
